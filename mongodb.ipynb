# %%
pip install pymongo
# Out:
# Requirement already satisfied: pymongo in d:\onedrive\desktop\github clone repo\livesensor\vevn\lib\site-packages (4.2.0)Note: you may need to restart the kernel to use updated packages.

# %%
import pymongo 
from pymongo import MongoClient

# %%
connection_string ="mongodb+srv://sksuvit2003:<db_passwordSksuvit@03@thapar123>@cluster0.aq13d.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
pip install pymongo[srv]
# Out:
# Requirement already satisfied: pymongo[srv] in d:\onedrive\desktop\github clone repo\livesensor\vevn\lib\site-packages (4.2.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in d:\onedrive\desktop\github clone repo\livesensor\vevn\lib\site-packages (from pymongo[srv]) (2.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
client=MongoClient(connection_string)
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 client=MongoClient(connection_string)
#
# File d:\OneDrive\Desktop\GITHUB CLONE REPO\LiveSensor\vevn\lib\site-packages\pymongo\mongo_client.py:726, in MongoClient.__init__(self, host, port, document_class, tz_aware, connect, type_registry, **kwargs)
#     722 if timeout is not None:
#     723     timeout = common.validate_timeout_or_none_or_zero(
#     724         keyword_opts.cased_key("connecttimeoutms"), timeout
#     725     )
# --> 726 res = uri_parser.parse_uri(
#     727     entity,
#     728     port,
#     729     validate=True,
#     730     warn=True,
#     731     normalize=False,
#     732     connect_timeout=timeout,
#     733     srv_service_name=srv_service_name,
#     734     srv_max_hosts=srv_max_hosts,
#     735 )
#     736 seeds.update(res["nodelist"])
#     737 username = res["username"] or username
#
# File d:\OneDrive\Desktop\GITHUB CLONE REPO\LiveSensor\vevn\lib\site-packages\pymongo\uri_parser.py:469, in parse_uri(uri, default_port, validate, warn, normalize, connect_timeout, srv_service_name, srv_max_hosts)
#     467 if not _HAVE_DNSPYTHON:
#     468     python_path = sys.executable or "python"
# --> 469     raise ConfigurationError(
#     470         'The "dnspython" module must be '
#     471         "installed to use mongodb+srv:// URIs. "
#     472         "To fix this error install pymongo with the srv extra:\n "
#     473         '%s -m pip install "pymongo[srv]"' % (python_path)
#     474     )
#     475 is_srv = True
#     476 scheme_free = uri[SRV_SCHEME_LEN:]
#
# ConfigurationError: The "dnspython" module must be installed to use mongodb+srv:// URIs. To fix this error install pymongo with the srv extra:
#  d:\OneDrive\Desktop\GITHUB CLONE REPO\LiveSensor\vevn\python.exe -m pip install "pymongo[srv]"
